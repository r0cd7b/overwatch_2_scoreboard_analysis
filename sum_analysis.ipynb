# %% [markdown]
# # 오버워치 2 점수판 분석 AI

# %%
import pandas as pd
from os import path
import joblib

players = 10


def prepare_scoreboards(defeat_, victory_):
    scoreboards_ = pd.concat([defeat_, victory_])
    scoreboards_.set_index(
        pd.Index((i, j) for i in range(len(scoreboards_.index) // players) for j in range(players)), inplace=True
    )
    return scoreboards_


datapath = path.join('datasets', '')
range_ = range(3, 10)
defeat = pd.read_csv(datapath + 'defeat.csv', usecols=range_)
victory = pd.read_csv(datapath + 'victory.csv', usecols=range_)
scoreboards = prepare_scoreboards(defeat, victory)
scoreboards.loc[
    (
            scoreboards['E'] == 0
    ) & (
            scoreboards['A'] == 0
    ) & (
            scoreboards['D'] == 0
    ) & (
            scoreboards['DMG'] == 0
    ) & (
            scoreboards['H'] == 0
    ) & (
            scoreboards['MIT'] == 0
    ), 'D'
] = scoreboards['D'].max()
scoreboards
# Out:
#         E   A   D    DMG      H   MIT    GAME
# 0   0   7   3   6   5933   1068  6199  DEFEAT
#     1   7   0  10   3601    747     0  DEFEAT
#     2   9   1   6   4352      0     0  DEFEAT
#     3   7   7   2   2332   6325     0  DEFEAT
#     4   6   4   2   3410   5979   606  DEFEAT
# ...    ..  ..  ..    ...    ...   ...     ...
# 396 5  15   1  13   8895      0  7164  DEFEAT
#     6  14   1  10   9021    264     0  DEFEAT
#     7  17   2   8  13526      0   317  DEFEAT
#     8   1  15   8   1703  10138   178  DEFEAT
#     9   5  14   4   2553  14656     0  DEFEAT
#
# [3970 rows x 7 columns]

# %%
from sklearn import utils

count = len(scoreboards.index) // players
scoreboards = scoreboards.loc[utils.shuffle(range(count))]
scoreboards
# Out:
#         E   A   D    DMG      H    MIT     GAME
# 186 0  19   3  11  12744      0  22464   DEFEAT
#     1  18   1   5   9596      0      0   DEFEAT
#     2  14   2  17   8583   1116      0   DEFEAT
#     3  13   6   9   6356  10715    319   DEFEAT
#     4   6   5  12   3072   9568     24   DEFEAT
# ...    ..  ..  ..    ...    ...    ...      ...
# 99  5   9   1   3   5547      0   9096  VICTORY
#     6  13   0   3   4340   1288      0  VICTORY
#     7   8   0   1   4513      0    106  VICTORY
#     8   0  12   2      0   3520      0  VICTORY
#     9  10   5   2   2532   4761      0  VICTORY
#
# [3970 rows x 7 columns]

# %%
X = scoreboards.drop('GAME', axis=1)
y = scoreboards['GAME'][::players].copy()

# %%
for i in range(count):
    X.loc[i, 0] -= X.loc[i, 5]
    X.loc[i, 1] += X.loc[i, 2] - X.loc[i, 6] - X.loc[i, 7]
    X.loc[i, 3] += X.loc[i, 4] - X.loc[i, 8] - X.loc[i, 9]
    X.drop([(i, 2), (i, 4), (i, 5), (i, 6), (i, 7), (i, 8), (i, 9)], inplace=True)

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler().fit(X)
X = pd.DataFrame(scaler.transform(X), X.index, X.columns)
X
# Out:
#               E         A         D       DMG         H       MIT
# 186 0  0.284483  0.346939  0.619718  0.411329  0.132187  0.656081
#     1  0.215517  0.438776  0.577465  0.240778  0.128061  0.477599
#     3  0.482759  0.142857  0.661972  0.585619  0.098904  0.479397
# 4   0  0.474138  0.459184  0.549296  0.443868  0.154490  0.322256
#     1  0.344828  0.408163  0.633803  0.367423  0.123025  0.463637
# ...         ...       ...       ...       ...       ...       ...
# 268 1  0.327586  0.469388  0.521127  0.230250  0.129375  0.428622
#     3  0.448276  0.326531  0.718310  0.451650  0.141600  0.504877
# 99  0  0.431034  0.479592  0.549296  0.459737  0.132187  0.488015
#     1  0.353448  0.459184  0.605634  0.398779  0.123179  0.501501
#     3  0.370690  0.387755  0.591549  0.361053  0.139397  0.493952
#
# [1191 rows x 6 columns]

# %%
players, features = X.loc[0].shape
total_features = players * features
X = X.values.reshape(-1, total_features)
print(X.shape)
print(y.shape)
# Out:
# (397, 18)
# (397,)

# %%
from sklearn import ensemble, linear_model, neighbors, neural_network, svm, tree, model_selection
import operator

estimators = (
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(n_jobs=-1),
    ensemble.ExtraTreesClassifier(n_jobs=-1),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(n_jobs=-1),
    ensemble.HistGradientBoostingClassifier(),
    linear_model.LogisticRegression(n_jobs=-1),
    linear_model.LogisticRegressionCV(max_iter=800, n_jobs=-1),
    linear_model.PassiveAggressiveClassifier(n_jobs=-1),
    linear_model.Perceptron(n_jobs=-1),
    linear_model.RidgeClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(n_jobs=-1),
    neighbors.KNeighborsClassifier(n_jobs=-1),
    neighbors.RadiusNeighborsClassifier(2., n_jobs=-1),
    neighbors.NearestCentroid(),
    neural_network.MLPClassifier(max_iter=1600),
    svm.LinearSVC(dual='auto'),
    svm.NuSVC(nu=.0625),
    svm.SVC(),
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier()
)
scores = [(estimator, model_selection.cross_val_score(estimator, X, y, n_jobs=-1).mean()) for estimator in estimators]
scores.sort(key=operator.itemgetter(1), reverse=True)
scores
# Out:
# [(LogisticRegressionCV(max_iter=800, n_jobs=-1), 0.9091772151898734),
#  (ExtraTreesClassifier(n_jobs=-1), 0.9042405063291138),
#  (LogisticRegression(n_jobs=-1), 0.9042088607594936),
#  (NearestCentroid(), 0.9041772151898734),
#  (SVC(), 0.8991772151898733),
#  (BaggingClassifier(n_jobs=-1), 0.8941455696202532),
#  (MLPClassifier(max_iter=1600), 0.8940822784810127),
#  (LinearSVC(dual='auto'), 0.8940822784810125),
#  (RandomForestClassifier(n_jobs=-1), 0.8916139240506329),
#  (RidgeClassifier(), 0.8915506329113925),
#  (RidgeClassifierCV(), 0.8865506329113924),
#  (KNeighborsClassifier(n_jobs=-1), 0.8815506329113925),
#  (GradientBoostingClassifier(), 0.8790822784810126),
#  (HistGradientBoostingClassifier(), 0.8740189873417721),
#  (SGDClassifier(n_jobs=-1), 0.8637025316455695),
#  (AdaBoostClassifier(), 0.8589240506329114),
#  (NuSVC(nu=0.0625), 0.84373417721519),
#  (ExtraTreeClassifier(), 0.8362974683544303),
#  (DecisionTreeClassifier(), 0.8362025316455697),
#  (Perceptron(n_jobs=-1), 0.8189873417721518),
#  (PassiveAggressiveClassifier(n_jobs=-1), 0.7985759493670886),
#  (RadiusNeighborsClassifier(n_jobs=-1, radius=2.0), 0.5163924050632912)]

# %%
defeats = len(defeat) // players


def find_file(index):
    index += 1
    if index <= defeats:
        return f'DEFEAT ({index})'
    else:
        index -= len(victory) // players
        return f'VICTORY ({index})'

# %%
for estimator, _ in scores:
    estimator = estimator.fit(X, y)
    if hasattr(estimator, 'feature_importances_'):
        print(estimator)
        importances = estimator.feature_importances_.reshape(-1, features)

        titles = '처치', '도움', '죽음', '피해', '치유', '경감'

        print('\n**특성 중요도**')
        for importance, title in sorted(zip(importances.sum(0), titles), reverse=True):
            print(f'{title}: {importance * 100:.0f}%')

        print('\n**1인 돌격 특성 중요도**')
        for importance, title in sorted(zip(importances[0], titles), reverse=True):
            print(f'{title}: {importance * 100:.0f}%')

        print('\n**1인 공격 특성 중요도**')
        for importance, title in sorted(zip(importances[1] / 2, titles), reverse=True):
            print(f'{title}: {importance * 100:.0f}%')

        print('\n**1인 지원 특성 중요도**')
        for importance, title in sorted(zip(importances[2] / 2, titles), reverse=True):
            print(f'{title}: {importance * 100:.0f}%')

        print('\n**1인 역할 중요도**')
        roles = importances.sum(1)
        for importance, title in sorted(zip((roles[0], roles[1] / 2, roles[2] / 2), ('돌격', '공격', '지원')), reverse=True):
            print(f'{title}: {importance * 100:.0f}%')

        break
# Out:
# ExtraTreesClassifier(n_jobs=-1)
#
# **특성 중요도**
# 처치: 34%
# 죽음: 27%
# 도움: 18%
# 피해: 10%
# 경감: 6%
# 치유: 5%
#
# **1인 돌격 특성 중요도**
# 처치: 14%
# 죽음: 9%
# 도움: 5%
# 피해: 4%
# 경감: 2%
# 치유: 2%
#
# **1인 공격 특성 중요도**
# 처치: 7%
# 죽음: 5%
# 피해: 2%
# 경감: 1%
# 도움: 1%
# 치유: 1%
#
# **1인 지원 특성 중요도**
# 도움: 5%
# 죽음: 4%
# 처치: 3%
# 피해: 1%
# 경감: 1%
# 치유: 1%
#
# **1인 역할 중요도**
# 돌격: 34%
# 공격: 17%
# 지원: 16%

# %%
from tensorflow.keras import backend, layers
from tensorflow import keras

backend.clear_session()
model = keras.Sequential()
model.add(layers.Dense(300, 'relu', input_shape=[total_features]))
model.add(layers.Dense(100, 'relu'))
model.add(layers.Dense(3, 'softmax'))
model.summary()
# Out:
# 2023-11-06 11:49:57.675090: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 300)               5700
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 36103 (141.03 KB)
# Trainable params: 36103 (141.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-11-06 11:49:58.882981: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:58.901754: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:58.902009: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:58.903299: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:58.903588: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:58.903817: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:59.013955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:59.014209: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:59.014222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-06 11:49:59.014606: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-06 11:49:59.014647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5572 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:06:00.0, compute capability: 8.6

# %%
from tensorflow.keras import optimizers, callbacks

encoder = preprocessing.LabelEncoder()
model.compile('sgd', 'sparse_categorical_crossentropy', ['accuracy'])
history = model.fit(
    X,
    encoder.fit_transform(y),
    epochs=100,
    verbose=2,
    callbacks=[callbacks.EarlyStopping(patience=10, restore_best_weights=True)],
    validation_split=.1
)
history.history['val_loss'][-11], history.history['val_accuracy'][-11]
# Out:
# Epoch 1/100
# 2023-11-06 11:50:00.013356: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-06 11:50:00.027820: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7847b00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-06 11:50:00.027855: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Ti, Compute Capability 8.6
# 2023-11-06 11:50:00.047021: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# 2023-11-06 11:50:00.056250: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-11-06 11:50:00.093230: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 12/12 - 1s - loss: 1.0984 - accuracy: 0.4846 - val_loss: 1.0143 - val_accuracy: 0.4750 - 827ms/epoch - 69ms/step
# Epoch 2/100
# 12/12 - 0s - loss: 0.9825 - accuracy: 0.4846 - val_loss: 0.9361 - val_accuracy: 0.4750 - 55ms/epoch - 5ms/step
# Epoch 3/100
# 12/12 - 0s - loss: 0.9134 - accuracy: 0.4846 - val_loss: 0.8825 - val_accuracy: 0.4750 - 52ms/epoch - 4ms/step
# Epoch 4/100
# 12/12 - 0s - loss: 0.8649 - accuracy: 0.4846 - val_loss: 0.8417 - val_accuracy: 0.4750 - 56ms/epoch - 5ms/step
# Epoch 5/100
# 12/12 - 0s - loss: 0.8264 - accuracy: 0.5014 - val_loss: 0.8081 - val_accuracy: 0.7500 - 58ms/epoch - 5ms/step
# Epoch 6/100
# 12/12 - 0s - loss: 0.7941 - accuracy: 0.8319 - val_loss: 0.7817 - val_accuracy: 0.8000 - 52ms/epoch - 4ms/step
# Epoch 7/100
# 12/12 - 0s - loss: 0.7683 - accuracy: 0.7647 - val_loss: 0.7587 - val_accuracy: 0.8500 - 50ms/epoch - 4ms/step
# Epoch 8/100
# 12/12 - 0s - loss: 0.7454 - accuracy: 0.8768 - val_loss: 0.7410 - val_accuracy: 0.9000 - 50ms/epoch - 4ms/step
# Epoch 9/100
# 12/12 - 0s - loss: 0.7273 - accuracy: 0.8655 - val_loss: 0.7258 - val_accuracy: 0.8500 - 48ms/epoch - 4ms/step
# Epoch 10/100
# 12/12 - 0s - loss: 0.7105 - accuracy: 0.8852 - val_loss: 0.7089 - val_accuracy: 0.9000 - 53ms/epoch - 4ms/step
# Epoch 11/100
# 12/12 - 0s - loss: 0.6931 - accuracy: 0.8852 - val_loss: 0.6956 - val_accuracy: 0.8750 - 54ms/epoch - 4ms/step
# Epoch 12/100
# 12/12 - 0s - loss: 0.6790 - accuracy: 0.8824 - val_loss: 0.6847 - val_accuracy: 0.9000 - 52ms/epoch - 4ms/step
# Epoch 13/100
# 12/12 - 0s - loss: 0.6662 - accuracy: 0.9020 - val_loss: 0.6735 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 14/100
# 12/12 - 0s - loss: 0.6551 - accuracy: 0.8908 - val_loss: 0.6637 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 15/100
# 12/12 - 0s - loss: 0.6440 - accuracy: 0.8768 - val_loss: 0.6544 - val_accuracy: 0.8750 - 47ms/epoch - 4ms/step
# Epoch 16/100
# 12/12 - 0s - loss: 0.6342 - accuracy: 0.8936 - val_loss: 0.6453 - val_accuracy: 0.8500 - 51ms/epoch - 4ms/step
# Epoch 17/100
# 12/12 - 0s - loss: 0.6244 - accuracy: 0.8515 - val_loss: 0.6375 - val_accuracy: 0.8500 - 53ms/epoch - 4ms/step
# Epoch 18/100
# 12/12 - 0s - loss: 0.6149 - accuracy: 0.8683 - val_loss: 0.6293 - val_accuracy: 0.8500 - 51ms/epoch - 4ms/step
# Epoch 19/100
# 12/12 - 0s - loss: 0.6047 - accuracy: 0.8739 - val_loss: 0.6222 - val_accuracy: 0.8750 - 48ms/epoch - 4ms/step
# Epoch 20/100
# 12/12 - 0s - loss: 0.5951 - accuracy: 0.8852 - val_loss: 0.6152 - val_accuracy: 0.8750 - 48ms/epoch - 4ms/step
# Epoch 21/100
# 12/12 - 0s - loss: 0.5859 - accuracy: 0.8936 - val_loss: 0.6066 - val_accuracy: 0.8500 - 50ms/epoch - 4ms/step
# Epoch 22/100
# 12/12 - 0s - loss: 0.5778 - accuracy: 0.8683 - val_loss: 0.5994 - val_accuracy: 0.8500 - 51ms/epoch - 4ms/step
# Epoch 23/100
# 12/12 - 0s - loss: 0.5686 - accuracy: 0.8711 - val_loss: 0.5916 - val_accuracy: 0.8250 - 61ms/epoch - 5ms/step
# Epoch 24/100
# 12/12 - 0s - loss: 0.5595 - accuracy: 0.8768 - val_loss: 0.5838 - val_accuracy: 0.8500 - 53ms/epoch - 4ms/step
# Epoch 25/100
# 12/12 - 0s - loss: 0.5506 - accuracy: 0.8880 - val_loss: 0.5766 - val_accuracy: 0.8500 - 49ms/epoch - 4ms/step
# Epoch 26/100
# 12/12 - 0s - loss: 0.5417 - accuracy: 0.8796 - val_loss: 0.5696 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 27/100
# 12/12 - 0s - loss: 0.5315 - accuracy: 0.8880 - val_loss: 0.5613 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 28/100
# 12/12 - 0s - loss: 0.5235 - accuracy: 0.8880 - val_loss: 0.5563 - val_accuracy: 0.9000 - 50ms/epoch - 4ms/step
# Epoch 29/100
# 12/12 - 0s - loss: 0.5141 - accuracy: 0.9020 - val_loss: 0.5491 - val_accuracy: 0.9000 - 55ms/epoch - 5ms/step
# Epoch 30/100
# 12/12 - 0s - loss: 0.5056 - accuracy: 0.9076 - val_loss: 0.5518 - val_accuracy: 0.8250 - 53ms/epoch - 4ms/step
# Epoch 31/100
# 12/12 - 0s - loss: 0.4995 - accuracy: 0.8936 - val_loss: 0.5345 - val_accuracy: 0.9000 - 49ms/epoch - 4ms/step
# Epoch 32/100
# 12/12 - 0s - loss: 0.4889 - accuracy: 0.9104 - val_loss: 0.5262 - val_accuracy: 0.8750 - 50ms/epoch - 4ms/step
# Epoch 33/100
# 12/12 - 0s - loss: 0.4796 - accuracy: 0.9048 - val_loss: 0.5234 - val_accuracy: 0.9000 - 49ms/epoch - 4ms/step
# Epoch 34/100
# 12/12 - 0s - loss: 0.4726 - accuracy: 0.9104 - val_loss: 0.5160 - val_accuracy: 0.9000 - 48ms/epoch - 4ms/step
# Epoch 35/100
# 12/12 - 0s - loss: 0.4639 - accuracy: 0.9104 - val_loss: 0.5093 - val_accuracy: 0.9000 - 50ms/epoch - 4ms/step
# Epoch 36/100
# 12/12 - 0s - loss: 0.4559 - accuracy: 0.9132 - val_loss: 0.4973 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 37/100
# 12/12 - 0s - loss: 0.4477 - accuracy: 0.9020 - val_loss: 0.4910 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 38/100
# 12/12 - 0s - loss: 0.4389 - accuracy: 0.9048 - val_loss: 0.4863 - val_accuracy: 0.9000 - 51ms/epoch - 4ms/step
# Epoch 39/100
# 12/12 - 0s - loss: 0.4322 - accuracy: 0.9104 - val_loss: 0.4809 - val_accuracy: 0.9000 - 50ms/epoch - 4ms/step
# Epoch 40/100
# 12/12 - 0s - loss: 0.4254 - accuracy: 0.9048 - val_loss: 0.4728 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 41/100
# 12/12 - 0s - loss: 0.4172 - accuracy: 0.9132 - val_loss: 0.4811 - val_accuracy: 0.8500 - 49ms/epoch - 4ms/step
# Epoch 42/100
# 12/12 - 0s - loss: 0.4146 - accuracy: 0.8992 - val_loss: 0.4677 - val_accuracy: 0.9000 - 52ms/epoch - 4ms/step
# Epoch 43/100
# 12/12 - 0s - loss: 0.4059 - accuracy: 0.9076 - val_loss: 0.4553 - val_accuracy: 0.8750 - 52ms/epoch - 4ms/step
# Epoch 44/100
# 12/12 - 0s - loss: 0.3983 - accuracy: 0.9076 - val_loss: 0.4589 - val_accuracy: 0.8750 - 46ms/epoch - 4ms/step
# Epoch 45/100
# 12/12 - 0s - loss: 0.3924 - accuracy: 0.9020 - val_loss: 0.4436 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 46/100
# 12/12 - 0s - loss: 0.3877 - accuracy: 0.9048 - val_loss: 0.4384 - val_accuracy: 0.8750 - 50ms/epoch - 4ms/step
# Epoch 47/100
# 12/12 - 0s - loss: 0.3812 - accuracy: 0.8992 - val_loss: 0.4339 - val_accuracy: 0.8750 - 51ms/epoch - 4ms/step
# Epoch 48/100
# 12/12 - 0s - loss: 0.3743 - accuracy: 0.9076 - val_loss: 0.4318 - val_accuracy: 0.9000 - 53ms/epoch - 4ms/step
# Epoch 49/100
# 12/12 - 0s - loss: 0.3696 - accuracy: 0.9104 - val_loss: 0.4331 - val_accuracy: 0.9000 - 49ms/epoch - 4ms/step
# Epoch 50/100
# 12/12 - 0s - loss: 0.3648 - accuracy: 0.9048 - val_loss: 0.4273 - val_accuracy: 0.9000 - 49ms/epoch - 4ms/step
# Epoch 51/100
# 12/12 - 0s - loss: 0.3617 - accuracy: 0.9048 - val_loss: 0.4176 - val_accuracy: 0.9000 - 49ms/epoch - 4ms/step
# Epoch 52/100
# 12/12 - 0s - loss: 0.3565 - accuracy: 0.9076 - val_loss: 0.4253 - val_accuracy: 0.8750 - 46ms/epoch - 4ms/step
# Epoch 53/100
# 12/12 - 0s - loss: 0.3531 - accuracy: 0.9104 - val_loss: 0.4160 - val_accuracy: 0.9000 - 49ms/epoch - 4ms/step
# Epoch 54/100
# 12/12 - 0s - loss: 0.3480 - accuracy: 0.9048 - val_loss: 0.4052 - val_accuracy: 0.8750 - 56ms/epoch - 5ms/step
# Epoch 55/100
# 12/12 - 0s - loss: 0.3446 - accuracy: 0.9048 - val_loss: 0.4016 - val_accuracy: 0.8750 - 48ms/epoch - 4ms/step
# Epoch 56/100
# 12/12 - 0s - loss: 0.3412 - accuracy: 0.9076 - val_loss: 0.4020 - val_accuracy: 0.8750 - 48ms/epoch - 4ms/step
# Epoch 57/100
# 12/12 - 0s - loss: 0.3364 - accuracy: 0.9104 - val_loss: 0.3983 - val_accuracy: 0.9000 - 53ms/epoch - 4ms/step
# Epoch 58/100
# 12/12 - 0s - loss: 0.3338 - accuracy: 0.9132 - val_loss: 0.4019 - val_accuracy: 0.9000 - 48ms/epoch - 4ms/step
# Epoch 59/100
# 12/12 - 0s - loss: 0.3313 - accuracy: 0.9104 - val_loss: 0.3918 - val_accuracy: 0.9000 - 50ms/epoch - 4ms/step
# Epoch 60/100
# 12/12 - 0s - loss: 0.3271 - accuracy: 0.9104 - val_loss: 0.3975 - val_accuracy: 0.9000 - 47ms/epoch - 4ms/step
# Epoch 61/100
# 12/12 - 0s - loss: 0.3248 - accuracy: 0.9048 - val_loss: 0.3851 - val_accuracy: 0.8750 - 52ms/epoch - 4ms/step
# Epoch 62/100
# 12/12 - 0s - loss: 0.3223 - accuracy: 0.9076 - val_loss: 0.3823 - val_accuracy: 0.8750 - 53ms/epoch - 4ms/step
# Epoch 63/100
# 12/12 - 0s - loss: 0.3224 - accuracy: 0.9104 - val_loss: 0.3816 - val_accuracy: 0.8750 - 53ms/epoch - 4ms/step
# Epoch 64/100
# 12/12 - 0s - loss: 0.3174 - accuracy: 0.9076 - val_loss: 0.3843 - val_accuracy: 0.8750 - 48ms/epoch - 4ms/step
# Epoch 65/100
# 12/12 - 0s - loss: 0.3156 - accuracy: 0.9076 - val_loss: 0.3877 - val_accuracy: 0.9000 - 49ms/epoch - 4ms/step
# Epoch 66/100
# 12/12 - 0s - loss: 0.3130 - accuracy: 0.9048 - val_loss: 0.3950 - val_accuracy: 0.8750 - 49ms/epoch - 4ms/step
# Epoch 67/100
# 12/12 - 0s - loss: 0.3138 - accuracy: 0.9020 - val_loss: 0.3758 - val_accuracy: 0.9000 - 51ms/epoch - 4ms/step
# Epoch 68/100
# 12/12 - 0s - loss: 0.3096 - accuracy: 0.9104 - val_loss: 0.3816 - val_accuracy: 0.9000 - 48ms/epoch - 4ms/step
# Epoch 69/100
# 12/12 - 0s - loss: 0.3082 - accuracy: 0.9076 - val_loss: 0.3852 - val_accuracy: 0.9000 - 51ms/epoch - 4ms/step
# Epoch 70/100
# 12/12 - 0s - loss: 0.3062 - accuracy: 0.9076 - val_loss: 0.3694 - val_accuracy: 0.8750 - 48ms/epoch - 4ms/step
# Epoch 71/100
# 12/12 - 0s - loss: 0.3077 - accuracy: 0.9076 - val_loss: 0.3682 - val_accuracy: 0.8750 - 48ms/epoch - 4ms/step
# Epoch 72/100
# 12/12 - 0s - loss: 0.3024 - accuracy: 0.9104 - val_loss: 0.3793 - val_accuracy: 0.9000 - 50ms/epoch - 4ms/step
# Epoch 73/100
# 12/12 - 0s - loss: 0.3013 - accuracy: 0.9104 - val_loss: 0.3695 - val_accuracy: 0.8750 - 51ms/epoch - 4ms/step
# Epoch 74/100
# 12/12 - 0s - loss: 0.3002 - accuracy: 0.9076 - val_loss: 0.3927 - val_accuracy: 0.8500 - 51ms/epoch - 4ms/step
# Epoch 75/100
# 12/12 - 0s - loss: 0.3015 - accuracy: 0.9020 - val_loss: 0.3648 - val_accuracy: 0.9000 - 54ms/epoch - 4ms/step
# Epoch 76/100
# 12/12 - 0s - loss: 0.2978 - accuracy: 0.9076 - val_loss: 0.3655 - val_accuracy: 0.8750 - 54ms/epoch - 4ms/step
# Epoch 77/100
# 12/12 - 0s - loss: 0.2973 - accuracy: 0.9104 - val_loss: 0.3709 - val_accuracy: 0.9000 - 48ms/epoch - 4ms/step
# Epoch 78/100
# 12/12 - 0s - loss: 0.2950 - accuracy: 0.9076 - val_loss: 0.3599 - val_accuracy: 0.8750 - 54ms/epoch - 5ms/step
# Epoch 79/100
# 12/12 - 0s - loss: 0.2951 - accuracy: 0.9132 - val_loss: 0.3588 - val_accuracy: 0.8750 - 50ms/epoch - 4ms/step
# Epoch 80/100
# 12/12 - 0s - loss: 0.2961 - accuracy: 0.9104 - val_loss: 0.3788 - val_accuracy: 0.8750 - 53ms/epoch - 4ms/step
# Epoch 81/100
# 12/12 - 0s - loss: 0.2935 - accuracy: 0.9104 - val_loss: 0.3650 - val_accuracy: 0.9000 - 52ms/epoch - 4ms/step
# Epoch 82/100
# 12/12 - 0s - loss: 0.2910 - accuracy: 0.9104 - val_loss: 0.3597 - val_accuracy: 0.8750 - 53ms/epoch - 4ms/step
# Epoch 83/100
# 12/12 - 0s - loss: 0.2899 - accuracy: 0.9104 - val_loss: 0.3573 - val_accuracy: 0.8750 - 54ms/epoch - 5ms/step
# Epoch 84/100
# 12/12 - 0s - loss: 0.2909 - accuracy: 0.9076 - val_loss: 0.3594 - val_accuracy: 0.8750 - 51ms/epoch - 4ms/step
# Epoch 85/100
# 12/12 - 0s - loss: 0.2899 - accuracy: 0.9104 - val_loss: 0.3585 - val_accuracy: 0.8750 - 47ms/epoch - 4ms/step
# Epoch 86/100
# 12/12 - 0s - loss: 0.2886 - accuracy: 0.9104 - val_loss: 0.3582 - val_accuracy: 0.8750 - 50ms/epoch - 4ms/step
# Epoch 87/100
# 12/12 - 0s - loss: 0.2890 - accuracy: 0.9104 - val_loss: 0.3594 - val_accuracy: 0.9000 - 50ms/epoch - 4ms/step
# Epoch 88/100
# 12/12 - 0s - loss: 0.2864 - accuracy: 0.9104 - val_loss: 0.3663 - val_accuracy: 0.9000 - 47ms/epoch - 4ms/step
# Epoch 89/100
# 12/12 - 0s - loss: 0.2850 - accuracy: 0.9104 - val_loss: 0.3548 - val_accuracy: 0.8750 - 50ms/epoch - 4ms/step
# Epoch 90/100
# 12/12 - 0s - loss: 0.2843 - accuracy: 0.9104 - val_loss: 0.3517 - val_accuracy: 0.8750 - 55ms/epoch - 5ms/step
# Epoch 91/100
# 12/12 - 0s - loss: 0.2845 - accuracy: 0.9104 - val_loss: 0.3565 - val_accuracy: 0.9000 - 53ms/epoch - 4ms/step
# Epoch 92/100
# 12/12 - 0s - loss: 0.2835 - accuracy: 0.9104 - val_loss: 0.3550 - val_accuracy: 0.9000 - 59ms/epoch - 5ms/step
# Epoch 93/100
# 12/12 - 0s - loss: 0.2823 - accuracy: 0.9132 - val_loss: 0.3675 - val_accuracy: 0.9000 - 54ms/epoch - 4ms/step
# Epoch 94/100
# 12/12 - 0s - loss: 0.2812 - accuracy: 0.9048 - val_loss: 0.3483 - val_accuracy: 0.8750 - 51ms/epoch - 4ms/step
# Epoch 95/100
# 12/12 - 0s - loss: 0.2853 - accuracy: 0.9048 - val_loss: 0.3480 - val_accuracy: 0.8750 - 55ms/epoch - 5ms/step
# Epoch 96/100
# 12/12 - 0s - loss: 0.2835 - accuracy: 0.9132 - val_loss: 0.3548 - val_accuracy: 0.9000 - 48ms/epoch - 4ms/step
# Epoch 97/100
# 12/12 - 0s - loss: 0.2797 - accuracy: 0.9104 - val_loss: 0.3488 - val_accuracy: 0.8500 - 48ms/epoch - 4ms/step
# Epoch 98/100
# 12/12 - 0s - loss: 0.2804 - accuracy: 0.9104 - val_loss: 0.3479 - val_accuracy: 0.8750 - 52ms/epoch - 4ms/step
# Epoch 99/100
# 12/12 - 0s - loss: 0.2799 - accuracy: 0.9104 - val_loss: 0.3476 - val_accuracy: 0.8500 - 60ms/epoch - 5ms/step
# Epoch 100/100
# 12/12 - 0s - loss: 0.2797 - accuracy: 0.9104 - val_loss: 0.3674 - val_accuracy: 0.8750 - 56ms/epoch - 5ms/step
# (0.351694792509079, 0.875)
